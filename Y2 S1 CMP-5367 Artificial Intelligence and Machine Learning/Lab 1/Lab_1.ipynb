# %% [markdown]
# <a href="https://colab.research.google.com/github/kacp-i/BCU-Work/blob/main/Y2%20S1%20CMP-5367%20Artificial%20Intelligence%20and%20Machine%20Learning/Lab%201/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## CMP5367 Lab 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Tooling setup, Interactive Notebooks and Data Manipulation

# %% [markdown]
# **Objectives:**
#
# In this lab you will:
# *  Recap on how to use IPython notebooks within the Google Colaboratory environment
# *   Set up your own IPython notebooks in Google Colab
# *   Recap on how to create Pandas Data Frames from existing excel / csv format datasets
# *   Recap on how to create Pandas Data Frames using data structures in Python
# *   Explore some basic data manipulation techniques using Python’s Pandas library

# %% [markdown]
# **Important**
#
# The labs are constructed in such a way that we expect you to ask further questions in class, to help develop a deeper understanding. If you find yourself getting stuck or feeling that you don’t fully understand an element of the task, don't panic! Just make sure you let us know as soon as possible.

# %% [markdown]
# # Review on Google Colab

# %% [markdown]
# **Exercise**:
# Open a new notebook [COLAB](https://colab.research.google.com)
#
# 1. Change the name of the notebook.
# 2. Add a code cell, run a print command in a code.
# 3. Check the libraries you have and clear the output.
# 4. Mount your Google Drive folder
# 5. Add a new text cell. Check the [Markdown Cheatsheet](https://www.markdownguide.org/cheat-sheet/) and do the following:
#
#   1. Include an image and a url in a text cell. Write a description of the image using bold and italics.
#   2. Include a list a text cell.
#   3. Include a table in a text cell, you can use the [Table Generator](https://www.tablesgenerator.com/markdown_tables)

# %% [markdown]
# # **Introducing Data Frames: Ingesting and manipulating data using Pandas library**

# %% [markdown]
# *   Before going any further, make sure you have downloaded the file “contact-lenses.csv” from Moodle to your local machine.
# *   On your GD create a folder named 'CMP5367' and within it, create a sub-folder called 'datasets'
#
# *   Download [contact-lenses.csv](https://moodle.bcu.ac.uk/mod/folder/view.php?id=8601575) and [iris.csv](https://moodle.bcu.ac.uk/mod/folder/view.php?id=8601575) Then Upload both into the 'datasets' folder

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/contact-lenses.csv')

# %%
df.head()
# Out:
#      age spectacle_prescrip astigmatism tear_prod_rate contact_lenses
# 0  young              myope          no        reduced           none
# 1  young              myope          no         normal           soft
# 2  young              myope         yes        reduced           none
# 3  young              myope         yes         normal           hard
# 4  young       hypermetrope          no        reduced           none

# %% [markdown]
# ## **Exercises**
# Please attempt the following exercise without looking at the solutions. Check the solutions after you give it a shot in finding the answer from your previous knowledge or from searching on the internet.
# Please make note of your answers as appropriate in a word document, notepad, or even your Python notebook!

# %% [markdown]
# ### **Exercise 1**
#
# As with many things in computing, getting used to effectively finding information in the official documentation for a given software system, library or programming language is an essential skill.
#
#
# Read through the [Intro to data structures](https://pandas.pydata.org/docs/user_guide/dsintro.html) section in the [Pandas User Guide](https://pandas.pydata.org/docs/user_guide/index.html) along with the Pandas cheat sheets linked on this week’s Moodle section, and try to answer the following questions, then discuss with your lab tutor once you think you have an appropriate set of answers.

# %% [markdown]
# ## Exercise 1A
#
# <b> What is a Pandas “Series” object?</b>
#
# an array (similar to a column)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# A pandas 'series' object is a flat array of data, similar to a table column.
#
# </details>

# %% [markdown]
# ## Exercise 1B
# <b> How is a Pandas “Data frame” different to a Pandas “Series”?</b>
#
# a data frame can store more complex data, compared to a series

# %% [markdown]
# <details><summary>Click here for the solution</summary>
# A pandas 'data frame' contains a multi-dimensional array of data, forming a table-like structure.
# A 'series' is a single-dimentional array.
# </details>

# %% [markdown]
# ## Exercise 1.C
#
# What are the difference between the *df.loc* and the *df.iloc* methods when trying to select a given record / row from our data set? In what circumstances would we use the 'loc' method and in what circumstances might *‘iloc’* be more appropriate?
#
# df.loc finds the location of an element based on the different labels (describers) attached to it, whereas df.iloc finds the location of an element based on the index of it
# df.loc would be best used in arrays which contain mostly non-numerical values, whereas df.iloc would work better on a mostly numerical array

# %% [markdown]
# <details><summary>Click here for the solution</summary>
# `df.iloc` finds results based on the position index. This is always numerical, similar to an array index. This could be useful when data is sorted, to find data stored in a specific position.
# `df.loc` finds results based on labels, which can be strings. This would be used when a data set has custom labels, and you need to find a specific record.
# </details>

# %% [markdown]
# ## Exercise 2: Exploration of Dataframe Attributes
# Read through the[“10 minutes to panda](https://pandas.pydata.org/docs/user_guide/10min.html)” and[“Essential basic functionalit](https://pandas.pydata.org/docs/user_guide/basics.html)” sections in the[ Pandas User Guide](https://pandas.pydata.org/docs/user_guide/index.html) along with the Pandas cheat sheet  linked on this week’s Moodle section, and try to answer the following questions, then discuss with your lab tutor once you think you have an appropriate set of answers

# %% [markdown]
# ## Exercise 2.A
# How might we extract the first 6 records from our contact lenses data frame?

# %%
df.head(6)
# Out:
#      age spectacle_prescrip astigmatism tear_prod_rate contact_lenses
# 0  young              myope          no        reduced           none
# 1  young              myope          no         normal           soft
# 2  young              myope         yes        reduced           none
# 3  young              myope         yes         normal           hard
# 4  young       hypermetrope          no        reduced           none
# 5  young       hypermetrope          no         normal           soft

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.head(6)
# ```
# </details>

# %% [markdown]
# ## Exercise 2.B
# How might we extract the last 3 records, from our contact lenses data frame?

# %%
df.tail(3)
# Out:
#            age spectacle_prescrip astigmatism tear_prod_rate contact_lenses
# 21  presbyopic       hypermetrope          no         normal           soft
# 22  presbyopic       hypermetrope         yes        reduced           none
# 23  presbyopic       hypermetrope         yes         normal           none

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.tail(3)
#
# ```
# </details>

# %% [markdown]
# ## Exercise 2.C
# How can we find out the names of the columns and their types in the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 24 non-null     object
#  1   spectacle_prescrip  24 non-null     object
#  2   astigmatism         24 non-null     object
#  3   tear_prod_rate      24 non-null     object
#  4   contact_lenses      24 non-null     object
# dtypes: object(5)
# memory usage: 1.1+ KB

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.columns
# df.dtypes
# ```
# </details>

# %% [markdown]
# ## Exercise 2.D
# What are the age groups in the dataset and how many instances we have in each age group?

# %%
df.value_counts('age')
# Out:
# age
# pre-presbyopic    8
# presbyopic        8
# young             8
# Name: count, dtype: int64

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df['age'].value_counts()
# ```
# </details>

# %% [markdown]
# ## Exercise 2.E
# How can we find statistical information about our dataframe?

# %%
df.describe()
# Out:
#           age spectacle_prescrip astigmatism tear_prod_rate contact_lenses
# count      24                 24          24             24             24
# unique      3                  2           2              2              3
# top     young              myope          no        reduced           none
# freq        8                 12          12             12             15

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.describe
# ```
# </details>

# %% [markdown]
# # Exercise 3: Extracting data from dataframe
# Read through the [Indexing and selecting data](https://pandas.pydata.org/docs/user_guide/indexing.html) section in the [Pandas User Guide](https://pandas.pydata.org/docs/user_guide/index.html) along with the Pandas cheat sheets linked on this week’s Moodle section, and try to answer the following questions, then discuss with your lab tutor once you think you have an appropriate set of answers

# %% [markdown]
# ## Exercise 3.A
# How might we select the third record from the data frame from our contact lenses data frame?

# %%
df.loc[2]
# Out:
# age                     young
# spectacle_prescrip      myope
# astigmatism               yes
# tear_prod_rate        reduced
# contact_lenses           none
# Name: 2, dtype: object

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.loc[2]
# ```
# </details>

# %% [markdown]
# ## Exercise 3.B
# From our contact lenses data frame, how might we select the value at the second column of the fourth record from the data frame?

# %%
df.iloc[3,1]
# Out:
# 'myope'

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.iloc[3,1]
# ```
# </details>

# %% [markdown]
# ## Exercise 3.C
# From our contact lenses data frame, how might we select **all** the **records** of the data frame **where the customer / patient does not have astigmatism?**

# %%
df[df['astigmatism'].str.contains('no')]
# Out:
#                age spectacle_prescrip astigmatism tear_prod_rate  \
# 0            young              myope          no        reduced
# 1            young              myope          no         normal
# 4            young       hypermetrope          no        reduced
# 5            young       hypermetrope          no         normal
# 8   pre-presbyopic              myope          no        reduced
# 9   pre-presbyopic              myope          no         normal
# 12  pre-presbyopic       hypermetrope          no        reduced
# 13  pre-presbyopic       hypermetrope          no         normal
# 16      presbyopic              myope          no        reduced
# 17      presbyopic              myope          no         normal
# 20      presbyopic       hypermetrope          no        reduced
# 21      presbyopic       hypermetrope          no         normal
#
#    contact_lenses
# 0            none
# 1            soft
# 4            none
# 5            soft
# 8            none
# 9            soft
# 12           none
# 13           soft
# 16           none
# 17           none
# 20           none
# 21           soft

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df[df['astigmatism'].str.contains('no')]
# ```
# </details>

# %% [markdown]
# ## Exercise 3.D
# From our contact lenses data frame notebook, how might we select **all** the records of the data frame **where the customer / patient is young and has soft contact lenses?**

# %%
df[(df['age'].str.contains("young")) & (~df['contact_lenses'].str.contains("none"))]
# Out:
#      age spectacle_prescrip astigmatism tear_prod_rate contact_lenses
# 1  young              myope          no         normal           soft
# 3  young              myope         yes         normal           hard
# 5  young       hypermetrope          no         normal           soft
# 7  young       hypermetrope         yes         normal           hard

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df[(df['age'].str.contains('young')) & (df['contact_lenses'].str.contains('soft'))]
# ```
# </details>

# %% [markdown]
# ## Exercise 4: Filtering dataframe
# Using the contents of the [Pandas user guide](https://pandas.pydata.org/docs/user_guide/index.html) and the Pandas cheat sheets found in this Week’s Moodle section, attempt the following exercises on the Contact lenses dataset (which can be downloaded from Moodle)

# %% [markdown]
# ### Exercise 4.A
# What is the “shape” of the contact lenses data frame, how might we find out by using Pandas?

# %%
df.shape
# Out:
# (24, 5)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.shape
# ```
# </details>

# %% [markdown]
# ### Exercise 4.B
# How might we sort the records in our data frame in descending order based on the values in the astigmatism column? The results should look something like this

# %%
df.sort_values(by = 'astigmatism', ascending = False)
# Out:
#                age spectacle_prescrip astigmatism tear_prod_rate  \
# 23      presbyopic       hypermetrope         yes         normal
# 2            young              myope         yes        reduced
# 3            young              myope         yes         normal
# 22      presbyopic       hypermetrope         yes        reduced
# 6            young       hypermetrope         yes        reduced
# 7            young       hypermetrope         yes         normal
# 19      presbyopic              myope         yes         normal
# 10  pre-presbyopic              myope         yes        reduced
# 11  pre-presbyopic              myope         yes         normal
# 18      presbyopic              myope         yes        reduced
# 14  pre-presbyopic       hypermetrope         yes        reduced
# 15  pre-presbyopic       hypermetrope         yes         normal
# 16      presbyopic              myope          no        reduced
# 21      presbyopic       hypermetrope          no         normal
# 20      presbyopic       hypermetrope          no        reduced
# 17      presbyopic              myope          no         normal
# 0            young              myope          no        reduced
# 13  pre-presbyopic       hypermetrope          no         normal
# 1            young              myope          no         normal
# 9   pre-presbyopic              myope          no         normal
# 8   pre-presbyopic              myope          no        reduced
# 5            young       hypermetrope          no         normal
# 4            young       hypermetrope          no        reduced
# 12  pre-presbyopic       hypermetrope          no        reduced
#
#    contact_lenses
# 23           none
# 2            none
# 3            hard
# 22           none
# 6            none
# 7            hard
# 19           hard
# 10           none
# 11           hard
# 18           none
# 14           none
# 15           none
# 16           none
# 21           soft
# 20           none
# 17           none
# 0            none
# 13           soft
# 1            soft
# 9            soft
# 8            none
# 5            soft
# 4            none
# 12           none

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.sort_values(by='astigmatism', ascending=False)
# ```
# </details>

# %% [markdown]
# ### Exercise 4.C
# How could we select records 2 to 4 in our contact lenses data frame?

# %%
df.iloc[2:5]
# Out:
#      age spectacle_prescrip astigmatism tear_prod_rate contact_lenses
# 2  young              myope         yes        reduced           none
# 3  young              myope         yes         normal           hard
# 4  young       hypermetrope          no        reduced           none

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.iloc[2:5]   # or df.loc[2:4]
# ```
# </details>

# %% [markdown]
# ### Exercise 4.D
# How could we select only those records that do not have astigmatism from records 2 to 4 in our contact lenses data frame?

# %%
df = df.iloc[2:5]
df[~df['astigmatism'].str.contains("no")]
# Out:
#      age spectacle_prescrip astigmatism tear_prod_rate contact_lenses
# 2  young              myope         yes        reduced           none
# 3  young              myope         yes         normal           hard

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df = df.iloc[2:5]
# df[df['astigmatism'].str.contains('no')]
# ```
# </details>

# %% [markdown]
# ### Exercise 4.E
# How could we select only those records that do not have astigmatism from records 2 to 4 in our contact lenses data frame?

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df = df.iloc[2:5]
# df[df['astigmatism'].str.contains('no')]
# ```
# </details>

# %% [markdown]
# ## Exercise 5
# Using the contents of the [Pandas user guide](https://pandas.pydata.org/docs/user_guide/index.html) and the Pandas cheat sheets found on this Week’s Moodle section, attempt the following exercises on the [Iris dataset](https://archive.ics.uci.edu/dataset/53/iris) (which can be downloaded from Moodle)

# %% [markdown]
# ## Iris dataset
# ![Iris Data](https://i.ytimg.com/vi/WLa8TwryugI/maxresdefault.jpg)

# %% [markdown]
# ## Exercise 5A
# Details of the Iris data set can be found here, based on these details by looking at our copy of the dataset what do you think the following column names represent?
# 1. Type
# 2. PW
# 3. PL
# 4. SW
# 5. SL
#
# - 1 - type of flower
# - 2 - petal width
# - 3 - petal length
# - 4 - sepal width
# - 5 - sepal length

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# 1. Type = The class of the iris plant
#
# 2. PW = Petal width
# 3. PL = Petal length
# 4. SW = Sepal width
# 5. SL = Sepal length
# </details>

# %% [markdown]
# ## Exercise 5.B
# How can we rename each of the columns with a more descriptive name for the data they contain?

# %%
df.rename(columns={
    "Type" : "Type of plant",
    "PW" : "Petal Width",
    "PL" : "Petal Length",
    "SW" : "Sepal Width",
    "SL" : "Sepal Length"
})

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# import pandas as pd
# df = pd.read_csv('/content/drive/MyDrive/CMP6202/datasets/iris.csv')
# df.rename(columns={
#     "Type": "Plant Class",
#     "PW": "Petal Width",
#     "PL": "Petal Length",
#     "SW": "Sepal Width",
#     "SL": "Sepal Length"
# })
# ```
# </details>

# %% [markdown]
# ### Exercise 5.C
# How can we select all those rows in the Iris dataset that have a PW greater than 10 and a PL greater than 50?

# %%
df[(df['Petal Width'] > 10) and (df['Petal Length'] > 50)]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df[(df['PW'] > 10) & (df['PL'] > 50)]
# ```
# </details>

# %% [markdown]
# ### Exercise 5.D
# How can we create a copy of the ‘Type’ column and name the new column in the data frame ‘Species’?

# %%
df['Species'] = df['Type of plant']

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df['Species'] = df['Type']
# df
# ```
# </details>

# %% [markdown]
# ### Exercise 5.E
# How can we write out our recently updated data frame to a new file in our datasets folder called ‘new_iris.csv’?

# %%
df.to_csv('new_iris.csv')

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.to_csv('/content/drive/MyDrive/CMP6202/datasets/new_iris.csv')
# ```
# </details>

# %% [markdown]
# # Advanced Exercise and write down the answers
#
# 1. Get the lowest and highest value of the Petal width for each class.
# 2. Get the shape and description of the iris dataset
# 3. Count the number of each Species in the dataset.
# 4. Get a new dataset that will display records only with species "Iris-setosa".
