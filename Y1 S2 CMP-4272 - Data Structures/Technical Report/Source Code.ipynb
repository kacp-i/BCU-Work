# %% [markdown]
# <a href="https://colab.research.google.com/github/kacp-i/BCU-Work/blob/main/Y1%20S2%20CMP-4272%20-%20Data%20Structures/Technical%20Report/Source%20Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section A1

# %%
import time
import numpy as np
import random
import copy

# %%
# Linear Search Algorithm

def linearSearch(lookingFor, lookingIn): # grabs what element is to be found and what list is to be looked through
  count = 0 # keeps track of index

  for elem in lookingIn: # loops through the list provided
    if elem == lookingFor: # checks if element being looked at is the one that is being searched for
      print("Located",lookingFor,"at index",count) # simple print statement
    else: # if the number is not found at this index, the index increases
      count += 1

# %%
# Binary Search Algorithm

def binarySearch(lookingIn, lookingFor, low, high):
  while low <= high: # repeat until the pointers low and high meet each other

    mid = low + (high - low) // 2 # finds midpoint of list

    if lookingIn[mid] == lookingFor: # checks if midpoint is number that is to be found
      print("Located",lookingFor,"at index",mid) # prints index of number
      break

    elif lookingIn[mid] < lookingFor: # checks if number is in lower half
      low = mid + 1

    else: # number in higher half
      high = mid - 1

# %%
# Selection Sort Algorithm

def selectionSort(lookingIn, listSize): # grabs the list to be sorted and the list size
  for elem in range(listSize): # looks at each element in the list
    minimumIndex = elem

    for sorting in range(elem + 1, listSize):
      if lookingIn[sorting] < lookingIn[minimumIndex]: #looks at the lowest number
        minimumIndex = sorting
    (lookingIn[elem], lookingIn[minimumIndex]) = (lookingIn[minimumIndex], lookingIn[elem]) #swaps elements in the list

  print("The list in Ascending Order:")
  print(lookingIn)

# %%
# Quick Sort Algorithm

def quickSort(lookingIn): # grabs the list to be sorted
  if len(lookingIn) <= 1: # checks if list is bigger than 1 element
    return lookingIn # returns number

  else:
    pivot = lookingIn[0] # sets the pivot as the 1st element in the list

    left = [x for x in lookingIn[1:] if x < pivot] # if element is smaller than pivot go to left
    right = [x for x in lookingIn[1:] if x >= pivot] # if element is bigger than / equal to pivot go to right

    return quickSort(left) + [pivot] + quickSort(right) # runs quick sort on the split lists, after all are done it concatinates the lists and pivot and returns sorted list

# %% [markdown]
# # Section A2

# %%
# Testing Linear Search

linList1 = [1, 5, 2, 7, 3, 19, 10, 42, 81]
linearSearch(19, linList1) #looking for number 19, found at index 5

linList2 = [1, 1, 1, 2, 2, 3, 6]
linearSearch(6, linList2) #looking for number 6, found at index 6

linList3 = [-12, 2, -19, -2001, 7, -90, 71, 24, 61, 57, -20002]
linearSearch(-20002, linList3) #looking for number -20002, found at index 10
# Out:
# Located 19 at index 5
# Located 6 at index 6
# Located -20002 at index 10

# %%
# Testing Binary Search

binList1 = [1, 4, 5, 8, 12, 24, 42, 81, 96, 102, 105, 252, 542]
binarySearch(binList1, 42, 0, len(binList1) - 1) #looking for number 42, found at index 6

binList2 = [1, 1, 5, 5, 5, 5, 7, 9, 10, 25, 71, 91, 98, 101, 222]
binarySearch(binList2, 222, 0, len(binList2) - 1) #looking for number 222, found at index 14

binList3 = [1, 2, 5, 17, 27, 39, 56, 81, 999, 1023, 1248]
binarySearch(binList3, 2, 0, len(binList3) - 1) #looking for number 2, found at index 1
# Out:
# Located 42 at index 6
# Located 222 at index 14
# Located 2 at index 1

# %%
# Testing Selection Sort

selList1 = [10, 8, 12, 4, 21, 56, 1, 12, 98, 101, 22]
selectionSort(selList1, len(selList1)) #sorted list should be [1, 4, 8, 10, 12, 12, 21, 22, 56, 98, 101]

selList2 = [17, 0, 1, 28, 11, -3, -2, -11, 91, 704]
selectionSort(selList2, len(selList2)) #sorted list should be [-11, -3, -2, 0, 1, 11, 17, 28, 91, 704]

selList3 = [-21, 1, -1, -18, -5, -120, -148, 0, -1011010101]
selectionSort(selList3, len(selList3)) #sorted list should be [-1011010101, -148, -120, -21, -18, -5, -1, 0, 1]
# Out:
# The list in Ascending Order:
# [1, 4, 8, 10, 12, 12, 21, 22, 56, 98, 101]
# The list in Ascending Order:
# [-11, -3, -2, 0, 1, 11, 17, 28, 91, 704]
# The list in Ascending Order:
# [-1011010101, -148, -120, -21, -18, -5, -1, 0, 1]

# %%
# Testing Quick Sort

quiList1 = [1, 7, 89, 19, 23, 191, 20, 13, 7, 8, 2, 7]
print("The list in Ascending Order")
print(quickSort(quiList1)) #sorted list should be [1, 2, 7, 7, 7, 8, 13, 19, 20, 23, 89, 191]

quiList2 = [2, 17, 11, 19, 31, 32, -11, 27, 18, 4]
print("The list in Ascending Order")
print(quickSort(quiList2)) #sorted list should be [-11, 2, 4, 11, 17, 18, 19, 27, 31, 32]

quiList3 = [-23, -70, -71, -9009, -732, 37, -91, -93, -61]
print("The list in Ascending Order")
print(quickSort(quiList3)) #sorted list should be [-9009, -732, -93, -91, -71, -70, -61, -23, 37]
# Out:
# The list in Ascending Order
# [1, 2, 7, 7, 7, 8, 13, 19, 20, 23, 89, 191]
# The list in Ascending Order
# [-11, 2, 4, 11, 17, 18, 19, 27, 31, 32]
# The list in Ascending Order
# [-9009, -732, -93, -91, -71, -70, -61, -23, 37]

# %% [markdown]
# # Section B1

# %%
def quickSortLast(lookingIn):
  if len(lookingIn) <= 1:
    return lookingIn

  else:
    pivot = lookingIn[-1] # sets the pivot as the last element in the list

    left = [x for x in lookingIn[:-1] if x < pivot]
    right = [x for x in lookingIn[:-1] if x >= pivot]

    return quickSortLast(left) + [pivot] + quickSortLast(right)

def quickSortRand(lookingIn):
  if len(lookingIn) <= 1:
    return lookingIn

  else:
    pivot = random.choice(lookingIn) # sets the pivot as a random element in the list

    left = [x for x in lookingIn if x < pivot]
    isPivot = [x for x in lookingIn if x == pivot] # grabs duplicate elements of the number which is pivot
    right = [x for x in lookingIn if x > pivot]

    return quickSortRand(left) + isPivot + quickSortRand(right)

# %%
# Generating lists with varying elem amounts
# testing with same lists across all sorts


sTestList5 = np.random.randint(10, size=5) # 5 elems
q1TestList5 = copy.deepcopy(sTestList5)
q2TestList5 = copy.deepcopy(sTestList5)
q3TestList5 = copy.deepcopy(sTestList5)

sTestList10 = np.random.randint(20, size=10) # 10 elems
q1TestList10 = copy.deepcopy(sTestList10)
q2TestList10 = copy.deepcopy(sTestList10)
q3TestList10 = copy.deepcopy(sTestList10)

sTestList15 = np.random.randint(30, size=15) # 15 elems
q1TestList15 = copy.deepcopy(sTestList15)
q2TestList15 = copy.deepcopy(sTestList15)
q3TestList15 = copy.deepcopy(sTestList15)

sTestList100 = np.random.randint(200, size=100) # 100 elems
q1TestList100 = copy.deepcopy(sTestList100)
q2TestList100 = copy.deepcopy(sTestList100)
q3TestList100 = copy.deepcopy(sTestList100)

sTestList1k = np.random.randint(2000, size=1000) # 1k elems
q1TestList1k = copy.deepcopy(sTestList1k)
q2TestList1k = copy.deepcopy(sTestList1k)
q3TestList1k = copy.deepcopy(sTestList1k)

sTestList10k = np.random.randint(20000, size=10000) # 10k elems
q1TestList10k = copy.deepcopy(sTestList10k)
q2TestList10k = copy.deepcopy(sTestList10k)
q3TestList10k = copy.deepcopy(sTestList10k)

# %% [markdown]
# # Selection Sort

# %%
# Selection Sort with 5 elems

t = time.time()
selectionSort(sTestList5, 5)
print(time.time() - t)
# Out:
# The list in Ascending Order:
# [1 1 5 6 9]
# 0.0048220157623291016

# %%
# Selection Sort with 10 elems

t = time.time()
selectionSort(sTestList10, 10)
print(time.time() - t)
# Out:
# The list in Ascending Order:
# [ 3  4  5  7  9 10 11 13 16 18]
# 0.004042863845825195

# %%
# Selection Sort with 15 elems

t = time.time()
selectionSort(sTestList15, 15)
print(time.time() - t)
# Out:
# The list in Ascending Order:
# [ 0  1  1  4  5 11 11 16 17 18 21 22 24 26 27]
# 0.002624034881591797

# %%
# Selection Sort with 100 elems

t = time.time()
selectionSort(sTestList100, 100)
print(time.time() - t)
# Out:
# The list in Ascending Order:
# [  4   5   8   9  10  13  13  17  18  19  22  22  24  25  27  28  30  30
#   32  34  34  35  35  35  35  38  39  40  43  44  47  47  53  53  59  59
#   60  62  62  68  68  68  73  74  77  77  79  82  85  87  89  91  92  94
#  101 102 104 106 107 109 115 119 119 123 125 128 130 132 135 144 144 144
#  145 148 149 151 154 154 155 158 161 165 165 167 167 168 169 169 171 172
#  176 177 177 179 182 184 187 190 193 196]
# 0.0051805973052978516

# %%
# Selection Sort with 1,000 elems

t = time.time()
selectionSort(sTestList1k, 1000)
print(time.time() - t)
# Out:
# The list in Ascending Order:
# [   1    3    4    5    5    9   10   14   14   14   16   18   21   22
#    23   28   33   35   39   41   43   45   47   53   54   56   57   58
#    58   60   61   63   64   64   66   68   78   78   79   80   82   82
#    85   86   86   87   87   93   96   97   97   98   98   99  100  101
#   102  103  106  108  110  111  112  112  116  118  118  120  123  127
#   129  129  132  132  136  139  139  140  141  145  145  146  147  148
#   150  153  153  154  155  158  167  168  168  169  169  170  171  172
#   172  174  177  179  184  185  187  189  189  191  194  196  199  201
#   203  205  206  207  212  213  213  217  218  224  225  225  226  227
#   234  235  239  245  246  249  259  261  262  262  265  267  267  268
#   269  270  273  273  277  280  287  288  288  290  295  296  299  301
#   301  304  304  305  307  307  309  309  310  312  316  316  318  319
#   320  323  323  324  336  338  341  346  348  349  352  357  359  364
# ...

# %%
# Selection Sort with 10,000 elems

t = time.time()
selectionSort(sTestList10k, 10000)
print(time.time() - t)
# Out:
# The list in Ascending Order:
# [    0     4     8 ... 19988 19991 19993]
# 26.21598792076111

# %% [markdown]
# # Quick Sort - 1st Pivot

# %%
# Quick Sort with 5 elems and 1st pivot

t = time.time()
print(quickSort(q1TestList5))
print(time.time() - t)
# Out:
# [1, 1, 5, 6, 9]
# 0.0002808570861816406

# %%
# Quick Sort with 10 elems and 1st pivot

t = time.time()
print(quickSort(q1TestList10))
print(time.time() - t)
# Out:
# [3, 4, 5, 7, 9, 10, 11, 13, 16, 18]
# 0.0011181831359863281

# %%
# Quick Sort with 15 elems and 1st pivot

t = time.time()
print(quickSort(q1TestList15))
print(time.time() - t)
# Out:
# [0, 1, 1, 4, 5, 11, 11, 16, 17, 18, 21, 22, 24, 26, 27]
# 0.0010972023010253906

# %%
# Quick Sort with 100 elems and 1st pivot

t = time.time()
print(quickSort(q1TestList100))
print(time.time() - t)
# Out:
# [4, 5, 8, 9, 10, 13, 13, 17, 18, 19, 22, 22, 24, 25, 27, 28, 30, 30, 32, 34, 34, 35, 35, 35, 35, 38, 39, 40, 43, 44, 47, 47, 53, 53, 59, 59, 60, 62, 62, 68, 68, 68, 73, 74, 77, 77, 79, 82, 85, 87, 89, 91, 92, 94, 101, 102, 104, 106, 107, 109, 115, 119, 119, 123, 125, 128, 130, 132, 135, 144, 144, 144, 145, 148, 149, 151, 154, 154, 155, 158, 161, 165, 165, 167, 167, 168, 169, 169, 171, 172, 176, 177, 177, 179, 182, 184, 187, 190, 193, 196]
# 0.0017902851104736328

# %%
# Quick Sort with 1k elems and 1st pivot

t = time.time()
print(quickSort(q1TestList1k))
print(time.time() - t)
# Out:
# [1, 3, 4, 5, 5, 9, 10, 14, 14, 14, 16, 18, 21, 22, 23, 28, 33, 35, 39, 41, 43, 45, 47, 53, 54, 56, 57, 58, 58, 60, 61, 63, 64, 64, 66, 68, 78, 78, 79, 80, 82, 82, 85, 86, 86, 87, 87, 93, 96, 97, 97, 98, 98, 99, 100, 101, 102, 103, 106, 108, 110, 111, 112, 112, 116, 118, 118, 120, 123, 127, 129, 129, 132, 132, 136, 139, 139, 140, 141, 145, 145, 146, 147, 148, 150, 153, 153, 154, 155, 158, 167, 168, 168, 169, 169, 170, 171, 172, 172, 174, 177, 179, 184, 185, 187, 189, 189, 191, 194, 196, 199, 201, 203, 205, 206, 207, 212, 213, 213, 217, 218, 224, 225, 225, 226, 227, 234, 235, 239, 245, 246, 249, 259, 261, 262, 262, 265, 267, 267, 268, 269, 270, 273, 273, 277, 280, 287, 288, 288, 290, 295, 296, 299, 301, 301, 304, 304, 305, 307, 307, 309, 309, 310, 312, 316, 316, 318, 319, 320, 323, 323, 324, 336, 338, 341, 346, 348, 349, 352, 357, 359, 364, 368, 369, 370, 371, 371, 375, 378, 379, 380, 380, 380, 382, 382, 386, 386, 387, 389, 393, 394, 396, 397, 399, 402, 405, 409, 410, 411, 414, 415, 41
# ...

# %%
# Quick Sort with 10k elems and 1st pivot

t = time.time()
print(quickSort(q1TestList10k))
print(time.time() - t)
# Out:
# [0, 4, 8, 9, 9, 15, 17, 18, 22, 22, 23, 24, 28, 28, 29, 30, 31, 31, 32, 32, 33, 33, 34, 34, 36, 36, 36, 37, 38, 40, 44, 44, 46, 46, 47, 54, 57, 59, 59, 60, 61, 62, 63, 67, 68, 76, 84, 87, 89, 89, 89, 89, 91, 92, 92, 93, 97, 99, 100, 102, 102, 103, 105, 105, 105, 106, 106, 109, 109, 110, 113, 117, 117, 118, 121, 122, 124, 124, 125, 127, 127, 131, 131, 131, 134, 135, 138, 139, 142, 142, 145, 146, 147, 147, 154, 155, 155, 155, 156, 161, 162, 163, 167, 176, 176, 178, 179, 180, 180, 181, 181, 182, 182, 183, 183, 184, 185, 190, 191, 192, 193, 196, 197, 197, 199, 199, 203, 205, 207, 208, 212, 214, 214, 215, 215, 216, 217, 217, 218, 222, 222, 222, 223, 224, 226, 230, 230, 233, 233, 233, 234, 240, 246, 247, 247, 249, 250, 255, 260, 261, 261, 262, 265, 269, 270, 271, 271, 272, 275, 278, 283, 284, 284, 291, 291, 291, 295, 295, 302, 308, 309, 309, 311, 314, 316, 323, 324, 324, 326, 327, 330, 333, 333, 336, 345, 347, 355, 361, 372, 372, 373, 376, 381, 384, 384, 384, 385, 389, 393, 394, 394, 396, 
# ...

# %% [markdown]
# # Quick Sort - Last Pivot

# %%
# Quick Sort with 5 elems and last pivot

t = time.time()
print(quickSortLast(q2TestList5))
print(time.time() - t)
# Out:
# [1, 1, 5, 6, 9]
# 0.00020813941955566406

# %%
# Quick Sort with 10 elems and last pivot

t = time.time()
print(quickSortLast(q2TestList10))
print(time.time() - t)
# Out:
# [3, 4, 5, 7, 9, 10, 11, 13, 16, 18]
# 0.0029115676879882812

# %%
# Quick Sort with 15 elems and last pivot

t = time.time()
print(quickSortLast(q2TestList15))
print(time.time() - t)
# Out:
# [0, 1, 1, 4, 5, 11, 11, 16, 17, 18, 21, 22, 24, 26, 27]
# 0.0002770423889160156

# %%
# Quick Sort with 100 elems and last pivot

t = time.time()
print(quickSortLast(q2TestList100))
print(time.time() - t)
# Out:
# [4, 5, 8, 9, 10, 13, 13, 17, 18, 19, 22, 22, 24, 25, 27, 28, 30, 30, 32, 34, 34, 35, 35, 35, 35, 38, 39, 40, 43, 44, 47, 47, 53, 53, 59, 59, 60, 62, 62, 68, 68, 68, 73, 74, 77, 77, 79, 82, 85, 87, 89, 91, 92, 94, 101, 102, 104, 106, 107, 109, 115, 119, 119, 123, 125, 128, 130, 132, 135, 144, 144, 144, 145, 148, 149, 151, 154, 154, 155, 158, 161, 165, 165, 167, 167, 168, 169, 169, 171, 172, 176, 177, 177, 179, 182, 184, 187, 190, 193, 196]
# 0.0026645660400390625

# %%
# Quick Sort with 1k elems and last pivot

t = time.time()
print(quickSortLast(q2TestList1k))
print(time.time() - t)
# Out:
# [1, 3, 4, 5, 5, 9, 10, 14, 14, 14, 16, 18, 21, 22, 23, 28, 33, 35, 39, 41, 43, 45, 47, 53, 54, 56, 57, 58, 58, 60, 61, 63, 64, 64, 66, 68, 78, 78, 79, 80, 82, 82, 85, 86, 86, 87, 87, 93, 96, 97, 97, 98, 98, 99, 100, 101, 102, 103, 106, 108, 110, 111, 112, 112, 116, 118, 118, 120, 123, 127, 129, 129, 132, 132, 136, 139, 139, 140, 141, 145, 145, 146, 147, 148, 150, 153, 153, 154, 155, 158, 167, 168, 168, 169, 169, 170, 171, 172, 172, 174, 177, 179, 184, 185, 187, 189, 189, 191, 194, 196, 199, 201, 203, 205, 206, 207, 212, 213, 213, 217, 218, 224, 225, 225, 226, 227, 234, 235, 239, 245, 246, 249, 259, 261, 262, 262, 265, 267, 267, 268, 269, 270, 273, 273, 277, 280, 287, 288, 288, 290, 295, 296, 299, 301, 301, 304, 304, 305, 307, 307, 309, 309, 310, 312, 316, 316, 318, 319, 320, 323, 323, 324, 336, 338, 341, 346, 348, 349, 352, 357, 359, 364, 368, 369, 370, 371, 371, 375, 378, 379, 380, 380, 380, 382, 382, 386, 386, 387, 389, 393, 394, 396, 397, 399, 402, 405, 409, 410, 411, 414, 415, 41
# ...

# %%
# Quick Sort with 10k elems and last pivot

t = time.time()
print(quickSortLast(q2TestList10k))
print(time.time() - t)
# Out:
# [0, 4, 8, 9, 9, 15, 17, 18, 22, 22, 23, 24, 28, 28, 29, 30, 31, 31, 32, 32, 33, 33, 34, 34, 36, 36, 36, 37, 38, 40, 44, 44, 46, 46, 47, 54, 57, 59, 59, 60, 61, 62, 63, 67, 68, 76, 84, 87, 89, 89, 89, 89, 91, 92, 92, 93, 97, 99, 100, 102, 102, 103, 105, 105, 105, 106, 106, 109, 109, 110, 113, 117, 117, 118, 121, 122, 124, 124, 125, 127, 127, 131, 131, 131, 134, 135, 138, 139, 142, 142, 145, 146, 147, 147, 154, 155, 155, 155, 156, 161, 162, 163, 167, 176, 176, 178, 179, 180, 180, 181, 181, 182, 182, 183, 183, 184, 185, 190, 191, 192, 193, 196, 197, 197, 199, 199, 203, 205, 207, 208, 212, 214, 214, 215, 215, 216, 217, 217, 218, 222, 222, 222, 223, 224, 226, 230, 230, 233, 233, 233, 234, 240, 246, 247, 247, 249, 250, 255, 260, 261, 261, 262, 265, 269, 270, 271, 271, 272, 275, 278, 283, 284, 284, 291, 291, 291, 295, 295, 302, 308, 309, 309, 311, 314, 316, 323, 324, 324, 326, 327, 330, 333, 333, 336, 345, 347, 355, 361, 372, 372, 373, 376, 381, 384, 384, 384, 385, 389, 393, 394, 394, 396, 
# ...

# %% [markdown]
# # Quick Sort - Random Pivot

# %%
# Quick Sort with 5 elems and random pivot

t = time.time()
print(quickSortRand(q3TestList5))
print(time.time() - t)
# Out:
# [1, 1, 5, 6, 9]
# 0.0009849071502685547

# %%
# Quick Sort with 10 elems and random pivot

t = time.time()
print(quickSortRand(q3TestList10))
print(time.time() - t)
# Out:
# [3, 4, 5, 7, 9, 10, 11, 13, 16, 18]
# 0.0028467178344726562

# %%
# Quick Sort with 15 elems and random pivot

t = time.time()
print(quickSortRand(q3TestList15))
print(time.time() - t)
# Out:
# [0, 1, 1, 4, 5, 11, 11, 16, 17, 18, 21, 22, 24, 26, 27]
# 0.0016565322875976562

# %%
# Quick Sort with 100 elems and random pivot

t = time.time()
print(quickSortRand(q3TestList100))
print(time.time() - t)
# Out:
# [4, 5, 8, 9, 10, 13, 13, 17, 18, 19, 22, 22, 24, 25, 27, 28, 30, 30, 32, 34, 34, 35, 35, 35, 35, 38, 39, 40, 43, 44, 47, 47, 53, 53, 59, 59, 60, 62, 62, 68, 68, 68, 73, 74, 77, 77, 79, 82, 85, 87, 89, 91, 92, 94, 101, 102, 104, 106, 107, 109, 115, 119, 119, 123, 125, 128, 130, 132, 135, 144, 144, 144, 145, 148, 149, 151, 154, 154, 155, 158, 161, 165, 165, 167, 167, 168, 169, 169, 171, 172, 176, 177, 177, 179, 182, 184, 187, 190, 193, 196]
# 0.002384662628173828

# %%
# Quick Sort witk 1k elems and random pivot

t = time.time()
print(quickSortRand(q3TestList1k))
print(time.time() - t)
# Out:
# [1, 3, 4, 5, 5, 9, 10, 14, 14, 14, 16, 18, 21, 22, 23, 28, 33, 35, 39, 41, 43, 45, 47, 53, 54, 56, 57, 58, 58, 60, 61, 63, 64, 64, 66, 68, 78, 78, 79, 80, 82, 82, 85, 86, 86, 87, 87, 93, 96, 97, 97, 98, 98, 99, 100, 101, 102, 103, 106, 108, 110, 111, 112, 112, 116, 118, 118, 120, 123, 127, 129, 129, 132, 132, 136, 139, 139, 140, 141, 145, 145, 146, 147, 148, 150, 153, 153, 154, 155, 158, 167, 168, 168, 169, 169, 170, 171, 172, 172, 174, 177, 179, 184, 185, 187, 189, 189, 191, 194, 196, 199, 201, 203, 205, 206, 207, 212, 213, 213, 217, 218, 224, 225, 225, 226, 227, 234, 235, 239, 245, 246, 249, 259, 261, 262, 262, 265, 267, 267, 268, 269, 270, 273, 273, 277, 280, 287, 288, 288, 290, 295, 296, 299, 301, 301, 304, 304, 305, 307, 307, 309, 309, 310, 312, 316, 316, 318, 319, 320, 323, 323, 324, 336, 338, 341, 346, 348, 349, 352, 357, 359, 364, 368, 369, 370, 371, 371, 375, 378, 379, 380, 380, 380, 382, 382, 386, 386, 387, 389, 393, 394, 396, 397, 399, 402, 405, 409, 410, 411, 414, 415, 41
# ...

# %%
# Quick Sort with 10k elems and random pivot

t = time.time()
print(quickSortRand(q3TestList10k))
print(time.time() - t)
# Out:
# [0, 4, 8, 9, 9, 15, 17, 18, 22, 22, 23, 24, 28, 28, 29, 30, 31, 31, 32, 32, 33, 33, 34, 34, 36, 36, 36, 37, 38, 40, 44, 44, 46, 46, 47, 54, 57, 59, 59, 60, 61, 62, 63, 67, 68, 76, 84, 87, 89, 89, 89, 89, 91, 92, 92, 93, 97, 99, 100, 102, 102, 103, 105, 105, 105, 106, 106, 109, 109, 110, 113, 117, 117, 118, 121, 122, 124, 124, 125, 127, 127, 131, 131, 131, 134, 135, 138, 139, 142, 142, 145, 146, 147, 147, 154, 155, 155, 155, 156, 161, 162, 163, 167, 176, 176, 178, 179, 180, 180, 181, 181, 182, 182, 183, 183, 184, 185, 190, 191, 192, 193, 196, 197, 197, 199, 199, 203, 205, 207, 208, 212, 214, 214, 215, 215, 216, 217, 217, 218, 222, 222, 222, 223, 224, 226, 230, 230, 233, 233, 233, 234, 240, 246, 247, 247, 249, 250, 255, 260, 261, 261, 262, 265, 269, 270, 271, 271, 272, 275, 278, 283, 284, 284, 291, 291, 291, 295, 295, 302, 308, 309, 309, 311, 314, 316, 323, 324, 324, 326, 327, 330, 333, 333, 336, 345, 347, 355, 361, 372, 372, 373, 376, 381, 384, 384, 384, 385, 389, 393, 394, 394, 396, 
# ...
